# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
numbers = np.random.random(100)
with open("//wsl.localhost/Ubuntu/home/morden/data/simple_data.txt", mode='w') as file:
    # This is for writing each number in the array in one line each
    for x in numbers:
        file.write(f"{x}\n")

# %%
# With numpy:

np.savetxt("//wsl.localhost/Ubuntu/home/morden/data/simple_data.txt", numbers)

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
matrix = np.random.random(size = (5,5))
with open("//wsl.localhost/Ubuntu/home/morden/data/data.txt", mode='w') as file:
    for row in matrix:
        file.write(" ".join(map(str, row)) + "\n")

# %%
# With numpy:

np.savetxt("//wsl.localhost/Ubuntu/home/morden/data/data.txt", matrix)

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import csv

with open('//wsl.localhost/Ubuntu/home/morden/data/data.txt', 'r') as data_file, \
    open('//wsl.localhost/Ubuntu/home/morden/data/data.csv', 'w', newline='') as csv_file:
    reader = csv.reader(data_file, delimiter=' ')
    writer = csv.writer(csv_file)
    for row in reader:
        if row:
            writer.writerow(row)

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with open('credit_card.dat', 'rb') as file:
    for line in file:
        bit_string = line.decode('utf-8').strip()
        card_number = []
        for i in range(0, len(bit_string) - 4, 6):
            six_bits = bit_string[i : i+6]
            
            if len(six_bits) == 6:
                char_code = int(six_bits, 2)
                card_number.append(chr(char_code))
        print("".join(card_number))
# Out:
# 7648 5673 3775 2271
# 3257 8247 3354 2266
# 2722 0001 4011 6652
# 0661 3063 3742 3150
# 0432 1608 1462 4742
# 5827 2027 8785 7303
# 5774 8528 2087 1117
# 8140 1210 6352 2845
# 5764 1133 7301 7100
# 6456 1737 4126 6726
# 1228 8631 7382 0000
# 7051 0160 5374 3166
# 0618 3587 1630 6376
# 1545 5454 7444 5636
# 6735 3116 3202 6834
# 7287 5011 1547 8413
# 7033 2607 3328 4200
# 2568 5244 1874 5024
# 1684 2253 7570 7118
# 0672 2576 0575 6631
# 6332 8353 8787 1340
# 1813 3361 1175 4211
# 2477 6450 8840 2368
# 5512 3505 2563 1326
# 3083 7882 0621 0025
# 4521 5148 8045 0334
# 7563 3654 8713 5787
# 8324 2664 0476 5561
# 0565 2504 7168 3510
# 5107 5507 1767 0738
# 2462 1821 2448 1443
# 2788 0638 6861 6554
# 5851 5873 5474 0547
# 0670 1004 4013 2655
# 5874 5506 3048 0806
# 2805 5401 8462 1260
# 5083 8406 6310 1862
# 1076 1445 3013 2266
# 8440 4804 4844 5277
# 4758 6141 0686 1387
# 7586 0675 0315 2568
# 2544 1258 7432 5165
# 3474 5023 4434 5626
# 1410 0270 0434 5086
# 7315 4446 1104 4215
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
# Pandas approach:

df = pd.read_json('user_data.json')
amex_data = df[df['CreditCardType'] == 'American Express']
amex_data.to_csv('user_data.csv', index=False)

# %%
# Numpy approach:

import json
import csv

with open('user_data.json', 'r') as f:
    user_data = json.load(f)

filtered_data = [user for user in user_data if user['CreditCardType'] == 'American Express']

if filtered_data:
    with open('user_data.csv', 'w', newline='') as csv_file:
        # keys from the first dictionary to use as a header
        fieldnames = filtered_data[0].keys()
        
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(filtered_data)

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import matplotlib.pyplot as plt

url = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
mushrooms_df = pd.read_csv(url)

print(mushrooms_df.info())
print(mushrooms_df.head())

mushrooms_df.hist("class")
plt.title("Distribution of Mushroom Classes")
plt.xlabel("Class (0 = Edible, 1 = Poisonous)")
plt.ylabel("Frequency")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int64
#  1   cap-shape                 8124 non-null   int64
#  2   cap-surface               8124 non-null   int64
#  3   cap-color                 8124 non-null   int64
#  4   bruises                   8124 non-null   int64
#  5   odor                      8124 non-null   int64
#  6   gill-attachment           8124 non-null   int64
#  7   gill-spacing              8124 non-null   int64
#  8   gill-size                 8124 non-null   int64
#  9   gill-color                8124 non-null   int64
#  10  stalk-shape               8124 non-null   int64
#  11  stalk-root                8124 non-null   int64
#  12  stalk-surface-above-ring  8124 non-null   int64
#  13  stalk-surface-below-ring  8124 non-null   int64
# ...

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url = 'https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'
regression_generated_df = pd.read_csv(url)

# %%
selected_features = regression_generated_df[['features_1', 'features_2', 'features_3']]
pd.plotting.scatter_matrix(selected_features, figsize=(10, 10))
plt.show()

# %%
pairs = [('features_1', 'features_2'), 
         ('features_1', 'features_3'), 
         ('features_2', 'features_3')]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, (feat_x, feat_y) in enumerate(pairs):
    axes[i].scatter(regression_generated_df[feat_x], regression_generated_df[feat_y], alpha=0.5)
    axes[i].set_title(f"{feat_x} vs {feat_y}")
    axes[i].set_xlabel(feat_x)
    axes[i].set_ylabel(feat_y)

plt.tight_layout()
plt.show()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
url = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
mushrooms_df = pd.read_csv(url)

# %%
mushrooms_df.to_json('mushroom.json', orient='records', indent=4)
